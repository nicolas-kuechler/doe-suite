# %% [markdown]
# # Script Demo
# Show how to use the provided scripts that help with creating expertiment designs and processing the results

# %% [markdown]
# ## Creating Experiment Design

# %% [markdown]
# ### Cross Product Experiment Design (from table format)
# Converts an experiment config in `table` form (concise) into the experiment design form required for the experiment suite.
# The function builds a cartesian product of all configuration options marked as `$FACTOR$` with a list of levels.
# The experiment in table form is a yaml file (with name `<exp_name>.yml` in `experiments/table`).
# Each factor of the experiment is a yaml object with a single entry with key `$FACTOR$` and as a value the list of levels.
#
# See example `experiments/table/demo.yml`and the resulting `experiments/designs/demo.yml`.

# %%
#%pycat scripts/expdesign.py # uncomment to see the code
# %run scripts/expdesign.py

experiment_design = build_config_product(exp_name="demo", n_repetitions=3)

display(experiment_design)
# Out:
# Writing experiment design to: experiments/designs/demo.yml
# {'n_repetitions': 3,
#  'base_experiment': {'a': 1,
#   'b': 'info',
#   'c': '$FACTOR$',
#   'd': '$FACTOR$',
#   'client': {'e': '$FACTOR$', 'test': {'f': 'cinfo'}},
#   'g': 'ginfo'},
#  'factor_levels': [{'c': 1, 'd': 4, 'client': {'e': 'V1'}},
#   {'c': 1, 'd': 4, 'client': {'e': 'V2'}},
#   {'c': 1, 'd': 5, 'client': {'e': 'V1'}},
#   {'c': 1, 'd': 5, 'client': {'e': 'V2'}},
#   {'c': 1, 'd': 6, 'client': {'e': 'V1'}},
#   {'c': 1, 'd': 6, 'client': {'e': 'V2'}},
#   {'c': 1, 'd': 7, 'client': {'e': 'V1'}},
#   {'c': 1, 'd': 7, 'client': {'e': 'V2'}},
#   {'c': 2, 'd': 4, 'client': {'e': 'V1'}},
#   {'c': 2, 'd': 4, 'client': {'e': 'V2'}},
#   {'c': 2, 'd': 5, 'client': {'e': 'V1'}},
#   {'c': 2, 'd': 5, 'client': {'e': 'V2'}},
#   {'c': 2, 'd': 6, 'client': {'e': 'V1'}},
#   {'c': 2, 'd': 6, 'client': {'e': 'V2'}},
#   {'c': 2, 'd': 7, 'client': {'e': 'V1'}},
#   {'c': 2, 'd': 7, 'client': {'e': 'V2'}},
#   {'c': 3, 'd': 4, 'client': {'e': 'V1'}},
#   {'c': 3, 'd': 4, 'client': {'e': 'V2'}},
#   {'c': 3, 'd': 5, 'client': {'e': 'V1'}},
#   {'c': 3, 'd': 5, 'client': {'e': 'V2'}},
#   {'c': 3, 'd': 6, 'client': {'e': 'V1'}},
#   {'c': 3, 'd': 6, 'client': {'e': 'V2'}},
#   {'c': 3, 'd': 7, 'client': {'e': 'V1'}},
#   {'c': 3, 'd': 7, 'client': {'e': 'V2'}}]}

# %% [markdown]
# ## Reading and Processing Results

# %%
import pandas as pd

results_dir = "results"

# %%
# A dict with all experiment names and for each a list of experiment ids that should be included in the dataframe.
# See `scripts/results.py` to adjust how different output files are used.  
exp = {
    "example" : ["1626083535"]
}

#%pycat scripts/results.py # uncomment to see the code
# %run scripts/results.py

df = read_df(results_dir, exp)
display(df)
# Out:
#    exp_name      exp_id    run    rep      host info  client.arg1  \
# 0   example  1626083535  run_1  rep_1  server_0   c2           10
# 1   example  1626083535  run_1  rep_1  client_0   c2           10
# 2   example  1626083535  run_1  rep_2  server_0   c2           10
# 3   example  1626083535  run_1  rep_2  client_0   c2           10
# 4   example  1626083535  run_1  rep_0  server_0   c2           10
# 5   example  1626083535  run_1  rep_0  client_0   c2           10
# 6   example  1626083535  run_0  rep_1  server_0   c1           10
# 7   example  1626083535  run_0  rep_1  client_0   c1           10
# 8   example  1626083535  run_0  rep_2  server_0   c1           10
# 9   example  1626083535  run_0  rep_2  client_0   c1           10
# 10  example  1626083535  run_0  rep_0  server_0   c1           10
# 11  example  1626083535  run_0  rep_0  client_0   c1           10
# 12  example  1626083535  run_2  rep_1  server_0   c3           10
# 13  example  1626083535  run_2  rep_1  client_0   c3           10
# 14  example  1626083535  run_2  rep_2  server_0   c3           10
# 15  example  1626083535  run_2  rep_2  client_0   c3           10
# 16  example  1626083535  run_2  rep_0  server_0   c3           10
# 17  example  1626083535  run_2  rep_0  client_0   c3           10
#
#     client.arg2  server.arg3 server.arg4   a0  a1   a2     a3  tp
# 0             2            2       test1  -a3   2  -a4  test1  14
# 1             2            2       test1  -a1  10  -a2      2  15
# 2             2            2       test1  -a3   2  -a4  test1   2
# 3             2            2       test1  -a1  10  -a2      2  12
# 4             2            2       test1  -a3   2  -a4  test1  11
# 5             2            2       test1  -a1  10  -a2      2   5
# 6             1            1       test1  -a3   1  -a4  test1   5
# 7             1            1       test1  -a1  10  -a2      1   4
# 8             1            1       test1  -a3   1  -a4  test1   3
# 9             1            1       test1  -a1  10  -a2      1   8
# 10            1            1       test1  -a3   1  -a4  test1  21
# 11            1            1       test1  -a1  10  -a2      1  19
# 12            3            3       test1  -a3   3  -a4  test1   2
# 13            3            3       test1  -a1  10  -a2      3   8
# 14            3            3       test1  -a3   3  -a4  test1   5
# 15            3            3       test1  -a1  10  -a2      3  19
# 16            3            3       test1  -a3   3  -a4  test1   3
# 17            3            3       test1  -a1  10  -a2      3  21

# %% [markdown]
# ### Group By (Aggregate Repetitions)
# The experiment repeats each run `r` times.
# Here we show how to apply this group by aggregate transformation on the dataframe to calculate mean, min, max, and std dev across repetitions of the same run.
# (for clarity, we exclude the other config options but they could be used as further group by columns)

# %%
# Example 1: Only keep the main info
df1 = df.groupby(['exp_name', 'exp_id', 'run', 'host']).agg({'tp': ['mean', 'min', 'max', 'std']}).reset_index()

df1.columns = ["_".join(v) if v[1] else v[0] for v in df1.columns.values]

display(df1)
# Out:
#   exp_name      exp_id    run      host      tp_mean tp_min tp_max    tp_std
# 0  example  1626083535  run_0  client_0    10.333333      4     19  7.767453
# 1  example  1626083535  run_0  server_0  1773.666667     21      5  9.865766
# 2  example  1626083535  run_1  client_0    10.666667      5     15  5.131601
# 3  example  1626083535  run_1  server_0  4737.000000     11      2  6.244998
# 4  example  1626083535  run_2  client_0    16.000000      8     21  7.000000
# 5  example  1626083535  run_2  server_0    84.333333      2      5  1.527525

# %%
# Example 2: Keep all config info
cols = df.columns.tolist()
cols.remove('rep') # remove rep because we want to aggregate over the reps
cols.remove('tp') # remove the `value` column `tp` (throughput)

df1 = df.groupby(cols).agg({'tp': ['mean', 'min', 'max', 'std']}).reset_index()
df1.columns = ["_".join(v) if v[1] else v[0] for v in df1.columns.values]
display(df1)
# Out:
#   exp_name      exp_id    run      host info  client.arg1  client.arg2  \
# 0  example  1626083535  run_0  client_0   c1           10            1
# 1  example  1626083535  run_0  server_0   c1           10            1
# 2  example  1626083535  run_1  client_0   c2           10            2
# 3  example  1626083535  run_1  server_0   c2           10            2
# 4  example  1626083535  run_2  client_0   c3           10            3
# 5  example  1626083535  run_2  server_0   c3           10            3
#
#    server.arg3 server.arg4   a0  a1   a2     a3      tp_mean tp_min tp_max  \
# 0            1       test1  -a1  10  -a2      1    10.333333      4     19
# 1            1       test1  -a3   1  -a4  test1  1773.666667     21      5
# 2            2       test1  -a1  10  -a2      2    10.666667      5     15
# 3            2       test1  -a3   2  -a4  test1  4737.000000     11      2
# 4            3       test1  -a1  10  -a2      3    16.000000      8     21
# 5            3       test1  -a3   3  -a4  test1    84.333333      2      5
#
#      tp_std
# 0  7.767453
# 1  9.865766
# 2  5.131601
# 3  6.244998
# 4  7.000000
# 5  1.527525
